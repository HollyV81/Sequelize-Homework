# %%
import pandas as pd
# Import SQL Alchemy
from sqlalchemy import create_engine

# Import PyMySQL (Not needed if mysqlclient is installed)
import pymysql
pymysql.install_as_MySQLdb()

# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float, Date,Text
from sqlalchemy.orm import Session, relationship

# %%
stations=pd.read_csv("hawaii_stations.csv")
measurements=pd.read_csv("clean_hawaii_measurements.csv")

# %%
engine = create_engine('sqlite:///hawaii4.sqlite')
conn = engine.connect()

# %%
class Stations(Base):
    __tablename__ = "stations"
    id= Column(Integer, primary_key=True) 
    station=Column(String)
    name=Column(String)
    latitude=Column(Float)
    longitude=Column(Float)
    elevation=Column(Float)

# %%
class Measurements(Base):
    __tablename__= "measurements"
    id= Column(Integer, primary_key=True) 
    station=Column(String)
    date=Column(Text)
    prcp=Column(Float)
    tobs=Column(Integer)

# %%
Base.metadata.create_all(bind=engine)
session= Session(bind=engine)

# %%
stations.to_sql('Stations', conn, if_exists='append', index=False)
# Out:
# C:\Users\holly\Anaconda3\lib\site-packages\pandas\io\sql.py:1168: UserWarning: The provided table name 'Stations' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
measurements.to_sql('Measurements', conn, if_exists='append', index=False)
# Out:
# C:\Users\holly\Anaconda3\lib\site-packages\pandas\io\sql.py:1168: UserWarning: The provided table name 'Measurements' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
station=session.query(Stations)
for station in station:
    print(station.__dict__)
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE4438>, 'longitude': -157.8168, 'name': 'WAIKIKI 717.2, HI US', 'id': 1, 'elevation': 3.0, 'latitude': 21.2716, 'station': 'USC00519397'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE44A8>, 'longitude': -157.8015, 'name': 'KANEOHE 838.1, HI US', 'id': 2, 'elevation': 14.6, 'latitude': 21.4234, 'station': 'USC00513117'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE4518>, 'longitude': -157.8374, 'name': 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 'id': 3, 'elevation': 7.0, 'latitude': 21.5213, 'station': 'USC00514830'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE45C0>, 'longitude': -157.9751, 'name': 'PEARL CITY, HI US', 'id': 4, 'elevation': 11.9, 'latitude': 21.3934, 'station': 'USC00517948'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE4668>, 'longitude': -158.0111, 'name': 'UPPER WAHIAWA 874.3, HI US', 'id': 5, 'elevation': 306.6, 'latitude': 21.4992, 'station': 'USC00518838'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE4710>, 'longitude': -157.71139, 'name': 'WAIMANALO EXPERIMENTAL FARM, HI US', 'id': 6, 'elevation': 19.5, 'latitude': 21.33556, 'station': 'USC00519523'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE47B8>, 'longitude': -157.84888999999998, 'name': 'WAIHEE 837.5, HI US', 'id': 7, 'elevation': 32.9, 'latitude': 21.45167, 'station': 'USC00519281'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE4860>, 'longitude': -157.9992, 'name': 'HONOLULU OBSERVATORY 702.2, HI US', 'id': 8, 'elevation': 0.9, 'latitude': 21.3152, 'station': 'USC00511918'}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE4908>, 'longitude': -157.8025, 'name': 'MANOA LYON ARBO 785.2, HI US', 'id': 9, 'elevation': 152.4, 'latitude': 21.3331, 'station': 'USC00516128'}

# %%
measure_id=session.query(Measurements)
for m in measure_id:
    print(m.__dict__)
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1A7EBBA8>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 65, 'date': '1/1/2010', 'id': 1}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1A7EB2E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 63, 'date': '1/2/2010', 'id': 2}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1A7EB358>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '1/3/2010', 'id': 3}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1A7EB9E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '1/4/2010', 'id': 4}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C34AE48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '1/6/2010', 'id': 5}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C34AA20>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 70, 'date': '1/7/2010', 'id': 6}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C34A5F8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64, 'date': '1/8/2010', 'id': 7}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C34A550>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '1/9/2010', 'id': 8}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C34A0B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '1/10/2010', 'id': 9}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C34A668>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 64, 'date': '1/11/2010', 'id': 10}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C34A0F0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 61, 'date': '1/12/2010', 'id': 11}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C34A358>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66, 'date': '1/14/2010', 'id': 12}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C302FD0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65, 'date': '1/15/2010', 'id': 13}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C3024E0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '1/16/2010', 'id': 14}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C302D30>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64, 'date': '1/17/2010', 'id': 15}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C3022B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '1/18/2010', 'id': 16}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C302668>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66, 'date': '1/19/2010', 'id': 17}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C302F28>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66, 'date': '1/20/2010', 'id': 18}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE47B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '1/21/2010', 'id': 19}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE45C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '1/22/2010', 'id': 20}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1CEE4F60>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '1/23/2010', 'id': 21}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E278>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 71, 'date': '1/24/2010', 'id': 22}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E320>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '1/25/2010', 'id': 23}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E3C8>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 76, 'date': '1/26/2010', 'id': 24}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E470>, 'prcp': 0.12, 'station': 'USC00519397', 'tobs': 68, 'date': '1/27/2010', 'id': 25}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E518>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '1/28/2010', 'id': 26}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E5C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70, 'date': '1/30/2010', 'id': 27}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E668>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 67, 'date': '1/31/2010', 'id': 28}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E710>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 66, 'date': '2/1/2010', 'id': 29}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E7B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2/3/2010', 'id': 30}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E860>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 69, 'date': '2/4/2010', 'id': 31}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E908>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2/5/2010', 'id': 32}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39E9B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2/6/2010', 'id': 33}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39EA58>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64, 'date': '2/7/2010', 'id': 34}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39EB00>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '2/8/2010', 'id': 35}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39EBA8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2/9/2010', 'id': 36}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39EC50>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2/11/2010', 'id': 37}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39ECF8>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 69, 'date': '2/12/2010', 'id': 38}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39EDA0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 69, 'date': '2/13/2010', 'id': 39}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39EE48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '2/14/2010', 'id': 40}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39EEF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71, 'date': '2/15/2010', 'id': 41}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C39EF98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 61, 'date': '2/16/2010', 'id': 42}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '2/17/2010', 'id': 43}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 63, 'date': '2/19/2010', 'id': 44}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E1D0>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 64, 'date': '2/20/2010', 'id': 45}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E278>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65, 'date': '2/21/2010', 'id': 46}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E320>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2/22/2010', 'id': 47}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E3C8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '2/23/2010', 'id': 48}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E470>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65, 'date': '2/24/2010', 'id': 49}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E518>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2/25/2010', 'id': 50}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E5C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2/26/2010', 'id': 51}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E668>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66, 'date': '2/28/2010', 'id': 52}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E710>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 70, 'date': '3/1/2010', 'id': 53}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E7B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '3/2/2010', 'id': 54}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '3/3/2010', 'id': 55}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E908>, 'prcp': 0.12, 'station': 'USC00519397', 'tobs': 70, 'date': '3/4/2010', 'id': 56}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92E9B0>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 71, 'date': '3/5/2010', 'id': 57}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92EA58>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 72, 'date': '3/6/2010', 'id': 58}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92EB00>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '3/7/2010', 'id': 59}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92EBA8>, 'prcp': 0.43, 'station': 'USC00519397', 'tobs': 69, 'date': '3/8/2010', 'id': 60}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92EC50>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 70, 'date': '3/9/2010', 'id': 61}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92ECF8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '3/11/2010', 'id': 62}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92EDA0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '3/12/2010', 'id': 63}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92EE48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '3/13/2010', 'id': 64}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92EEF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70, 'date': '3/14/2010', 'id': 65}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C92EF98>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 71, 'date': '3/15/2010', 'id': 66}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '3/17/2010', 'id': 67}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70, 'date': '3/18/2010', 'id': 68}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9321D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '3/21/2010', 'id': 69}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932278>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '3/22/2010', 'id': 70}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932320>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '3/23/2010', 'id': 71}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9323C8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '3/24/2010', 'id': 72}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932470>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '3/26/2010', 'id': 73}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932518>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '3/27/2010', 'id': 74}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9325C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '3/28/2010', 'id': 75}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932668>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '3/29/2010', 'id': 76}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932710>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '3/30/2010', 'id': 77}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9327B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '3/31/2010', 'id': 78}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '4/1/2010', 'id': 79}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932908>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 74, 'date': '4/2/2010', 'id': 80}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9329B0>, 'prcp': 0.17, 'station': 'USC00519397', 'tobs': 74, 'date': '4/3/2010', 'id': 81}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932A58>, 'prcp': 0.15, 'station': 'USC00519397', 'tobs': 71, 'date': '4/4/2010', 'id': 82}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932B00>, 'prcp': 0.27, 'station': 'USC00519397', 'tobs': 72, 'date': '4/5/2010', 'id': 83}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932BA8>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 75, 'date': '4/6/2010', 'id': 84}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932C50>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '4/8/2010', 'id': 85}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932CF8>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 75, 'date': '4/9/2010', 'id': 86}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932DA0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '4/10/2010', 'id': 87}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932E48>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 73, 'date': '4/11/2010', 'id': 88}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932EF0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 73, 'date': '4/12/2010', 'id': 89}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C932F98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71, 'date': '4/13/2010', 'id': 90}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71, 'date': '4/15/2010', 'id': 91}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939128>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 68, 'date': '4/16/2010', 'id': 92}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9391D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70, 'date': '4/17/2010', 'id': 93}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939278>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71, 'date': '4/18/2010', 'id': 94}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939320>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '4/19/2010', 'id': 95}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9393C8>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 71, 'date': '4/20/2010', 'id': 96}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939470>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 75, 'date': '4/21/2010', 'id': 97}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939518>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '4/22/2010', 'id': 98}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9395C0>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 75, 'date': '4/23/2010', 'id': 99}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939668>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '4/24/2010', 'id': 100}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939710>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '4/25/2010', 'id': 101}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9397B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '4/26/2010', 'id': 102}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '4/28/2010', 'id': 103}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939908>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '4/30/2010', 'id': 104}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9399B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/1/2010', 'id': 105}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939A58>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 73, 'date': '5/2/2010', 'id': 106}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939B00>, 'prcp': 0.2, 'station': 'USC00519397', 'tobs': 74, 'date': '5/3/2010', 'id': 107}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939BA8>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 76, 'date': '5/4/2010', 'id': 108}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939C50>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 76, 'date': '5/5/2010', 'id': 109}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939CF8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '5/6/2010', 'id': 110}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939DA0>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 74, 'date': '5/7/2010', 'id': 111}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939E48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/8/2010', 'id': 112}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939EF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/9/2010', 'id': 113}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C939F98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '5/10/2010', 'id': 114}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/11/2010', 'id': 115}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '5/13/2010', 'id': 116}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F1D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '5/14/2010', 'id': 117}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F278>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '5/15/2010', 'id': 118}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F320>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 73, 'date': '5/16/2010', 'id': 119}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F3C8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/17/2010', 'id': 120}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F470>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '5/18/2010', 'id': 121}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F518>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/19/2010', 'id': 122}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F5C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/21/2010', 'id': 123}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F668>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '5/22/2010', 'id': 124}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F710>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 75, 'date': '5/23/2010', 'id': 125}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F7B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/24/2010', 'id': 126}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/25/2010', 'id': 127}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F908>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 77, 'date': '5/26/2010', 'id': 128}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93F9B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '5/27/2010', 'id': 129}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FA58>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '5/28/2010', 'id': 130}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FB00>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/29/2010', 'id': 131}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FBA8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/30/2010', 'id': 132}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FC50>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '5/31/2010', 'id': 133}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FCF8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/1/2010', 'id': 134}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FDA0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 76, 'date': '6/2/2010', 'id': 135}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FE48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/3/2010', 'id': 136}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FEF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '6/4/2010', 'id': 137}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C93FF98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '6/5/2010', 'id': 138}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/6/2010', 'id': 139}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '6/7/2010', 'id': 140}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9471D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/8/2010', 'id': 141}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947278>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/9/2010', 'id': 142}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947320>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '6/10/2010', 'id': 143}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9473C8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/11/2010', 'id': 144}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947470>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/12/2010', 'id': 145}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947518>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/13/2010', 'id': 146}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9475C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '6/14/2010', 'id': 147}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947668>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/15/2010', 'id': 148}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947710>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/16/2010', 'id': 149}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9477B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '6/17/2010', 'id': 150}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '6/18/2010', 'id': 151}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947908>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 82, 'date': '6/19/2010', 'id': 152}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9479B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/20/2010', 'id': 153}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947A58>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/21/2010', 'id': 154}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947B00>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/22/2010', 'id': 155}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947BA8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/23/2010', 'id': 156}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947C50>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/24/2010', 'id': 157}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947CF8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '6/25/2010', 'id': 158}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947DA0>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 76, 'date': '6/26/2010', 'id': 159}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947E48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/27/2010', 'id': 160}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947EF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/28/2010', 'id': 161}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C947F98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/29/2010', 'id': 162}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '6/30/2010', 'id': 163}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F128>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 75, 'date': '7/1/2010', 'id': 164}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F1D0>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 77, 'date': '7/2/2010', 'id': 165}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F278>, 'prcp': 0.09, 'station': 'USC00519397', 'tobs': 77, 'date': '7/3/2010', 'id': 166}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F320>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 78, 'date': '7/4/2010', 'id': 167}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F3C8>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 78, 'date': '7/5/2010', 'id': 168}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F470>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 76, 'date': '7/6/2010', 'id': 169}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F518>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 74, 'date': '7/7/2010', 'id': 170}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F5C0>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 76, 'date': '7/8/2010', 'id': 171}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F668>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 74, 'date': '7/9/2010', 'id': 172}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F710>, 'prcp': 0.09, 'station': 'USC00519397', 'tobs': 76, 'date': '7/10/2010', 'id': 173}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F7B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '7/11/2010', 'id': 174}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '7/12/2010', 'id': 175}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F908>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '7/13/2010', 'id': 176}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94F9B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '7/16/2010', 'id': 177}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FA58>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 76, 'date': '7/17/2010', 'id': 178}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FB00>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '7/18/2010', 'id': 179}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FBA8>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 77, 'date': '7/19/2010', 'id': 180}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FC50>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '7/21/2010', 'id': 181}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FCF8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '7/22/2010', 'id': 182}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FDA0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '7/24/2010', 'id': 183}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FE48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '7/25/2010', 'id': 184}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FEF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '7/26/2010', 'id': 185}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C94FF98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '7/27/2010', 'id': 186}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '7/28/2010', 'id': 187}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '7/29/2010', 'id': 188}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9571D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '7/30/2010', 'id': 189}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957278>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 77, 'date': '7/31/2010', 'id': 190}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957320>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 77, 'date': '8/1/2010', 'id': 191}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9573C8>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 76, 'date': '8/2/2010', 'id': 192}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957470>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 77, 'date': '8/3/2010', 'id': 193}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957518>, 'prcp': 0.07, 'station': 'USC00519397', 'tobs': 77, 'date': '8/4/2010', 'id': 194}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9575C0>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 75, 'date': '8/5/2010', 'id': 195}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957668>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 75, 'date': '8/6/2010', 'id': 196}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957710>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '8/7/2010', 'id': 197}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9577B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '8/8/2010', 'id': 198}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '8/9/2010', 'id': 199}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957908>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '8/10/2010', 'id': 200}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9579B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '8/11/2010', 'id': 201}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957A58>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '8/12/2010', 'id': 202}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957B00>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '8/13/2010', 'id': 203}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957BA8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '8/14/2010', 'id': 204}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957C50>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 76, 'date': '8/15/2010', 'id': 205}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957CF8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '8/16/2010', 'id': 206}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957DA0>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 74, 'date': '8/17/2010', 'id': 207}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957E48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '8/18/2010', 'id': 208}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957EF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '8/19/2010', 'id': 209}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C957F98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '8/20/2010', 'id': 210}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '8/21/2010', 'id': 211}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '8/22/2010', 'id': 212}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E1D0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 87, 'date': '8/23/2010', 'id': 213}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E278>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '8/24/2010', 'id': 214}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E320>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 76, 'date': '8/25/2010', 'id': 215}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E3C8>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 78, 'date': '8/26/2010', 'id': 216}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E470>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '8/27/2010', 'id': 217}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E518>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 79, 'date': '8/28/2010', 'id': 218}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E5C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '8/29/2010', 'id': 219}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E668>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '8/30/2010', 'id': 220}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E710>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '8/31/2010', 'id': 221}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E7B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '9/1/2010', 'id': 222}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E860>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 76, 'date': '9/2/2010', 'id': 223}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E908>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 78, 'date': '9/3/2010', 'id': 224}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95E9B0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 77, 'date': '9/4/2010', 'id': 225}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95EA58>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '9/5/2010', 'id': 226}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95EB00>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '9/6/2010', 'id': 227}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95EBA8>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 76, 'date': '9/7/2010', 'id': 228}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95EC50>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/8/2010', 'id': 229}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95ECF8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/9/2010', 'id': 230}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95EDA0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/10/2010', 'id': 231}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95EE48>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 78, 'date': '9/11/2010', 'id': 232}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95EEF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '9/12/2010', 'id': 233}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C95EF98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/13/2010', 'id': 234}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '9/14/2010', 'id': 235}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '9/15/2010', 'id': 236}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9671D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '9/16/2010', 'id': 237}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967278>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/17/2010', 'id': 238}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967320>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/19/2010', 'id': 239}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9673C8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/20/2010', 'id': 240}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967470>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '9/21/2010', 'id': 241}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967518>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 76, 'date': '9/22/2010', 'id': 242}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9675C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/23/2010', 'id': 243}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967668>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/24/2010', 'id': 244}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967710>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '9/25/2010', 'id': 245}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9677B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '9/26/2010', 'id': 246}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '9/27/2010', 'id': 247}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967908>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '9/28/2010', 'id': 248}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C9679B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '9/29/2010', 'id': 249}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967A58>, 'prcp': 0.57, 'station': 'USC00519397', 'tobs': 73, 'date': '9/30/2010', 'id': 250}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967B00>, 'prcp': 0.31, 'station': 'USC00519397', 'tobs': 78, 'date': '10/1/2010', 'id': 251}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967BA8>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 78, 'date': '10/2/2010', 'id': 252}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967C50>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '10/3/2010', 'id': 253}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967CF8>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 78, 'date': '10/4/2010', 'id': 254}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967DA0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '10/5/2010', 'id': 255}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967E48>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '10/6/2010', 'id': 256}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967EF0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '10/7/2010', 'id': 257}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C967F98>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '10/8/2010', 'id': 258}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '10/9/2010', 'id': 259}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '10/10/2010', 'id': 260}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D1D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '10/11/2010', 'id': 261}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D278>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '10/12/2010', 'id': 262}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D320>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '10/13/2010', 'id': 263}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D3C8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '10/15/2010', 'id': 264}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D470>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '10/16/2010', 'id': 265}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D518>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '10/17/2010', 'id': 266}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D5C0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '10/18/2010', 'id': 267}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D668>, 'prcp': 0.07, 'station': 'USC00519397', 'tobs': 72, 'date': '10/19/2010', 'id': 268}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D710>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '10/20/2010', 'id': 269}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D7B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '10/21/2010', 'id': 270}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '10/22/2010', 'id': 271}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D908>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '10/23/2010', 'id': 272}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96D9B0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '10/24/2010', 'id': 273}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96DA58>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '10/25/2010', 'id': 274}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96DB00>, 'prcp': 0.07, 'station': 'USC00519397', 'tobs': 76, 'date': '10/26/2010', 'id': 275}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96DBA8>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 79, 'date': '10/27/2010', 'id': 276}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1C96DC50>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 78, 'date': '10/28/2010', 'id': 277}
# ...
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA2F98>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 71, 'date': '5/16/2010', 'id': 15090}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8080>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '5/17/2010', 'id': 15091}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8128>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '5/18/2010', 'id': 15092}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA81D0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '5/19/2010', 'id': 15093}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8278>, 'prcp': 0.03, 'station': 'USC00511918', 'tobs': 71, 'date': '5/20/2010', 'id': 15094}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8320>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 74, 'date': '5/21/2010', 'id': 15095}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA83C8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '5/22/2010', 'id': 15096}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8470>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '5/23/2010', 'id': 15097}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8518>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '5/24/2010', 'id': 15098}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA85C0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 73, 'date': '5/25/2010', 'id': 15099}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8668>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 73, 'date': '5/26/2010', 'id': 15100}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8710>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 67, 'date': '5/27/2010', 'id': 15101}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA87B8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 67, 'date': '5/28/2010', 'id': 15102}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8860>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '5/30/2010', 'id': 15103}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8908>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '5/31/2010', 'id': 15104}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA89B0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '6/1/2010', 'id': 15105}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8A58>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '6/2/2010', 'id': 15106}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8B00>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '6/3/2010', 'id': 15107}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8BA8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '6/4/2010', 'id': 15108}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8C50>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '6/5/2010', 'id': 15109}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8CF8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '6/6/2010', 'id': 15110}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8DA0>, 'prcp': 0.05, 'station': 'USC00511918', 'tobs': 69, 'date': '6/7/2010', 'id': 15111}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8E48>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '6/8/2010', 'id': 15112}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8EF0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '6/9/2010', 'id': 15113}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECA8F98>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '6/10/2010', 'id': 15114}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF080>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '6/11/2010', 'id': 15115}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF128>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '6/12/2010', 'id': 15116}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF1D0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '6/14/2010', 'id': 15117}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF278>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '6/15/2010', 'id': 15118}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF320>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '6/16/2010', 'id': 15119}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF3C8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '6/17/2010', 'id': 15120}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF470>, 'prcp': 0.04, 'station': 'USC00511918', 'tobs': 72, 'date': '6/18/2010', 'id': 15121}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF518>, 'prcp': 0.05, 'station': 'USC00511918', 'tobs': 78, 'date': '6/19/2010', 'id': 15122}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF5C0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 85, 'date': '6/20/2010', 'id': 15123}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF668>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '6/21/2010', 'id': 15124}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF710>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '6/22/2010', 'id': 15125}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF7B8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '6/23/2010', 'id': 15126}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF860>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '6/24/2010', 'id': 15127}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF908>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 71, 'date': '6/25/2010', 'id': 15128}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAF9B0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 70, 'date': '6/26/2010', 'id': 15129}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFA58>, 'prcp': 0.09, 'station': 'USC00511918', 'tobs': 80, 'date': '6/27/2010', 'id': 15130}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFB00>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '6/28/2010', 'id': 15131}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFBA8>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 70, 'date': '6/29/2010', 'id': 15132}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFC50>, 'prcp': 0.03, 'station': 'USC00511918', 'tobs': 73, 'date': '6/30/2010', 'id': 15133}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFCF8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '7/3/2010', 'id': 15134}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFDA0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '7/4/2010', 'id': 15135}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFE48>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 78, 'date': '7/5/2010', 'id': 15136}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFEF0>, 'prcp': 0.1, 'station': 'USC00511918', 'tobs': 71, 'date': '7/6/2010', 'id': 15137}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECAFF98>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 70, 'date': '7/7/2010', 'id': 15138}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8080>, 'prcp': 0.03, 'station': 'USC00511918', 'tobs': 74, 'date': '7/8/2010', 'id': 15139}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8128>, 'prcp': 0.15, 'station': 'USC00511918', 'tobs': 72, 'date': '7/9/2010', 'id': 15140}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB81D0>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 76, 'date': '7/10/2010', 'id': 15141}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8278>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '7/12/2010', 'id': 15142}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8320>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '7/13/2010', 'id': 15143}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB83C8>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 77, 'date': '7/14/2010', 'id': 15144}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8470>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 79, 'date': '7/15/2010', 'id': 15145}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8518>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '7/16/2010', 'id': 15146}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB85C0>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 74, 'date': '7/17/2010', 'id': 15147}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8668>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '7/18/2010', 'id': 15148}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8710>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 70, 'date': '7/19/2010', 'id': 15149}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB87B8>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 74, 'date': '7/20/2010', 'id': 15150}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8860>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '7/21/2010', 'id': 15151}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8908>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '7/22/2010', 'id': 15152}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB89B0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 72, 'date': '7/23/2010', 'id': 15153}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8A58>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '7/24/2010', 'id': 15154}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8B00>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '7/25/2010', 'id': 15155}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8BA8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '7/26/2010', 'id': 15156}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8C50>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 68, 'date': '7/27/2010', 'id': 15157}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8CF8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 69, 'date': '7/28/2010', 'id': 15158}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8DA0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '7/29/2010', 'id': 15159}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8E48>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '7/30/2010', 'id': 15160}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8EF0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '7/31/2010', 'id': 15161}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECB8F98>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '8/1/2010', 'id': 15162}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0080>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '8/2/2010', 'id': 15163}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0128>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 72, 'date': '8/3/2010', 'id': 15164}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC01D0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 72, 'date': '8/4/2010', 'id': 15165}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0278>, 'prcp': 0.04, 'station': 'USC00511918', 'tobs': 69, 'date': '8/5/2010', 'id': 15166}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0320>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 77, 'date': '8/6/2010', 'id': 15167}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC03C8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 73, 'date': '8/7/2010', 'id': 15168}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0470>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 78, 'date': '8/8/2010', 'id': 15169}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0518>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '8/9/2010', 'id': 15170}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC05C0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 83, 'date': '8/10/2010', 'id': 15171}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0668>, 'prcp': 0.1, 'station': 'USC00511918', 'tobs': 74, 'date': '8/11/2010', 'id': 15172}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0710>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '8/12/2010', 'id': 15173}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC07B8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '8/13/2010', 'id': 15174}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0860>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '8/14/2010', 'id': 15175}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0908>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '8/15/2010', 'id': 15176}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC09B0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '8/16/2010', 'id': 15177}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0A58>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 73, 'date': '8/17/2010', 'id': 15178}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BA1ECC0B00>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 70, 'date': '8/18/2010', 'id': 15179}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
